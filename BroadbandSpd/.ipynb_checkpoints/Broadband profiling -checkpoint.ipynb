# %%
import pandas as pd

# %%
df = pd.read_csv('bband_camden.csv')

# %%
df.head()
# Out:
#       OA11CD   Median16     Mean16      Min16       Max16   Median17  \
# 0  E00004527  18.784615  27.400000   5.592308   92.338462  19.620000
# 1  E00004525  24.220000  33.200000  13.133333   83.860000  25.072727
# 2  E00004522  23.172727  29.890909   8.259091   83.390909  25.223810
# 3  E00004287  37.550000  49.350000  14.900000  150.500000  54.500000
# 4  E00004206  34.925000  51.225000  15.850000  138.000000  49.950000
#
#       Mean17      Min17       Max17   LSOA11CD
# 0  32.833333   7.986667  102.220000  E01000918
# 1  36.690909  11.300000  103.709091  E01000918
# 2  34.119048  10.123810  100.542857  E01000919
# 3  58.020000  17.800000  180.000000  E01000875
# 4  62.625000  11.600000  175.000000  E01000858

# %%
df.shape
# Out:
# (749, 10)

# %%
df.isna().sum().plot(kind='bar')

# %%
import geopandas 
import matplotlib.pyplot as 
# %matplotlib inline

# %%
df2 = geopandas.read_file('bband_camden.shp')
df2
# Out:
#         OA11CD     Median16       Mean16        Min16        Max16  \
# 0    E00004527  18.78461538         27.4  5.592307692  92.33846154
# 1    E00004525        24.22         33.2  13.13333333        83.86
# 2    E00004522  23.17272727  29.89090909  8.259090909  83.39090909
# 3    E00004287        37.55        49.35         14.9        150.5
# 4    E00004206       34.925       51.225        15.85          138
# 5    E00004200        27.68  33.02666667  14.35333333  72.43333333
# 6    E00004281       48.125        52.55         7.85          128
# 7    E00004464           50        54.15        11.85          150
# 8    E00004460        31.18        38.08         8.36        88.36
# 9    E00004461           40        48.45         1.25          200
# 10   E00174650        31.12        30.54         6.24        49.14
# 11   E00174657        35.14        33.52         8.28        72.86
# 12   E00174654  23.65714286  30.65714286  5.028571429  81.85714286
# ...

# %%
df2.geometry.plot();

# %%
# %pwd
# Out:
# 'C:\\Users\\shub7\\Desktop\\BroadbandSpd'

# %%
a = df[df.isna().any(axis='columns')]

# %%
df.shape[0]
# Out:
# 749

# %%
a.count()/df.shape[0]
# Out:
# OA11CD      0.009346
# Median16    0.001335
# Mean16      0.002670
# Min16       0.004005
# Max16       0.004005
# Median17    0.004005
# Mean17      0.004005
# Min17       0.004005
# Max17       0.004005
# LSOA11CD    0.009346
# dtype: float64

# %%
df.describe()
# Out:
#          Median16      Mean16       Min16       Max16    Median17      Mean17  \
# count  743.000000  744.000000  745.000000  745.000000  745.000000  745.000000
# mean    34.172933   44.720818    8.095865  137.954405   40.348710   53.715204
# std     14.239630   13.074494   10.107389   39.108498   12.896678   17.418854
# min      3.000000    3.400000    0.300000    6.166600    2.800000    3.100000
# 25%     25.050000   37.893750    5.083333  114.340000   31.516667   45.500000
# 50%     33.580000   45.036667    7.100000  142.483333   40.140000   54.014286
# 75%     41.938393   52.080000    9.533333  166.220000   50.000000   62.140000
# max    237.565217  239.173913  223.017391  250.395652   88.633333  367.000000
#
#             Min17       Max17
# count  745.000000  745.000000
# mean     8.482213  159.297476
# std      3.970130   41.002602
# min      0.300000    6.400000
# 25%      5.650000  138.000000
# 50%      7.866667  163.422222
# 75%     10.842857  191.666667
# ...

# %%
df.dtypes
# Out:
# OA11CD       object
# Median16    float64
# Mean16      float64
# Min16       float64
# Max16       float64
# Median17    float64
# Mean17      float64
# Min17       float64
# Max17       float64
# LSOA11CD     object
# dtype: object
